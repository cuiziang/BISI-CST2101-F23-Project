# %% [markdown]
# # BISI CST2101 Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ### Q1: Import the necessary libraries and briefly explain the use of each library (1 Mark)

# %%
# remove _____ & write the appropriate library name

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# You don't have to explain about these libraries below
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 1:
#
# Nump is used for numerical calculations.
# Pandas is used for data manipulation and analysis.
# Seaborn is used for data visualization.
# Matplotlib is used for data visualization.
# Sklearn is used for machine learning.

# %% [markdown]
# ### Q2: Read the given dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ### Q3. Show the last 5 records of the dataset (1 Mark)

# %%
#remove ______ and write the appropriate number in the function

pima.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 995            2      173             79             32      474  35.504233
# 996           13      132             70             30      111  35.271769
# 997            3      132             87             44      156  34.794755
# 998            0      140              0              0        0  41.926693
# 999            4       93             59             35       93  45.914499
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                  0.402867   21        1
# 996                  0.168845   42        1
# 997                  0.765003   29        1
# 998                  0.209833   28        1
# 999                  0.737636   29        1

# %% [markdown]
# ### Q4. Show the first 5 records of the dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Q5. Find the dimension of the `pima` dataframe. What do you understand by the dimension of the dataset? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5:
# The dimension of the dataset is the number of rows and columns in the dataset.
# In the case of the dataset of pima, the dimension is 1000 rows and 9 columns.

# %% [markdown]
# ### Q6. Find the size of the `pima` dataframe. (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.size
# Out:
# 9000

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6:
# The size of the dataframe is the number of elements in the dataframe.
# For example, the size of pima dataframe is 9000 .

# %% [markdown]
# ### Q7. Display the data types of all the variables in the data set? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ### Q8. Are there any missing values in the `pima` dataframe?  Which variables have missing values? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 8:
# No variable has missing values.

# %% [markdown]
# ### Q9. Find the summary statistics for all variables except for  `'Outcome'` variable? Choose any one column/variable and explain all the statistical measures. (2 Marks)

# %%
#remove _____ & write the appropriate function name

pima.iloc[:, [i for i in range(pima.shape[1]) if i != pima.columns.get_loc('Outcome')]].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      4.051000   125.21600      69.072000      20.755000    83.086000
# std       3.325576    32.27772      20.465328      16.008599   117.255326
# min       0.000000     0.00000       0.000000       0.000000     0.000000
# 25%       1.000000   102.00000      64.000000       0.000000     0.000000
# 50%       3.000000   122.00000      72.000000      24.000000    23.000000
# 75%       6.000000   146.00000      80.000000      33.000000   133.500000
# max      17.000000   199.00000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  1000.000000               1000.000000  1000.000000
# mean     32.664772                  0.494090    33.830000
# std       7.563614                  0.322158    11.268189
# min       0.000000                  0.078000    21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 9:
# I choose the 'Glucose' variable.
# The count of the 'Glucose' variable is 1000. This means that there are 1000 people in the dataset.
# The mean of the 'Glucose' variable is 125.216. This means that the average glucose level of the 1000 people is 125.216.
# The standard deviation of the 'Glucose' variable is 32.27772. This means that the glucose level of the 1000 people is spread out over a range of 32.27772.
# The minimum value of the 'Glucose' variable is 0. This means that the lowest glucose level of the 1000 people is 0.
# The 25th percentile of the 'Glucose' variable is 102. This means that 25% of the people have a glucose level of 102 or less.
# The 50th percentile of the 'Glucose' variable is 122. This means that 50% of the people have a glucose level of 122 or less.
# The 75th percentile of the 'Glucose' variable is 146. This means that 75% of the people have a glucose level of 146 or less.
# The maximum value of the 'Glucose' variable is 199. This means that the highest glucose level of the 1000 people is 199.

# %% [markdown]
# ### Q10. Plot the distribution plot for the variable `'BloodPressure'`. Write your observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate library name

sns.displot(pima['BloodPressure'], kde=True)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 10:
#
# The distribution plot for the variable 'BloodPressure' is a normal distribution.
# The highest frequency of blood pressure is between 70 and 80.
# The lowest frequency of blood pressure is between 0 and 10.
# The average blood pressure is between 60 and 70.
# The blood pressure is spread out over a range of 100.

# %% [markdown]
# ### Q11. What is the `'BMI'` for the person having the highest `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose'] == pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 11:
# The BMI for the person having the highest Glucose is 42.9.

# %% [markdown]
# ### Q12.
# #### 12.1 What is the mean of the variable `'BMI'`?
# #### 12.2 What is the median of the variable `'BMI'`?
# #### 12.3 What is the mode of the variable `'BMI'`?
# #### 12.4 Are the three measures of central tendency equal?
#
# ### (2 Marks)

# %%
#remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median()  #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 32.664772391408796
# 32.8
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
# 12.1 The mean of the variable 'BMI' is 32.66.
# 12.2 The median of the variable 'BMI' is 32.8.
# 12.3 The mode of the variable 'BMI' is 32.0.
# 12.4 The three measures of central tendency are not equal.

# %% [markdown]
# ### Q13. How many women's `'Glucose'` level is above the mean level of `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose'] > pima['Glucose'].mean()].shape[0]
# Out:
# 449

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13:
# The women's Glucose level is above the mean level of Glucose is 449.

# %% [markdown]
# ### Q14. Create the pairplot for variables `'Glucose'`, `'SkinThickness'` and `'DiabetesPedigreeFunction'`. Write you observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate function and argument names

sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 14:
#
# The Glucose level of the people who are diabetic is higher than the Glucose level of the people who are not diabetic.
# The SkinThickness of the people who are diabetic is higher than the SkinThickness of the people who are not diabetic.
# The DiabetesPedigreeFunction of the people who are diabetic is higher than the DiabetesPedigreeFunction of the people who are not diabetic.

# %% [markdown]
# ### Q15. Plot the scatterplot between `'Glucose'` and `'Insulin'`. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name

sns.scatterplot(x='Glucose', y='Insulin', data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 15:
# The Glucose level of the people who are diabetic is higher than the Glucose level of the people who are not diabetic.
# The Insulin level of the people who are diabetic is higher than the Insulin level of the people who are not diabetic.
# The Glucose level and the Insulin level are positively correlated.
# The Glucose level and the Insulin level are spread out over a range of 200.

# %% [markdown]
# ### Q16. Plot the boxplot for the 'Age' variable. Are there outliers? (1 Mark)

# %%
#remove _____ & write the appropriate function and column name 

plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 16:
# Yes, there are outliers.
# Because there are dots outside the whiskers.

# %% [markdown]
# ### Q17. Find and visualize the the correlation matrix. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name and run the code

corr_matrix = pima.iloc[:, 0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.112930       0.127463      -0.080033
# Glucose                      0.112930  1.000000       0.134993       0.050656
# BloodPressure                0.127463  0.134993       1.000000       0.249063
# SkinThickness               -0.080033  0.050656       0.249063       1.000000
# Insulin                     -0.064909  0.334175       0.117369       0.472663
# BMI                          0.012920  0.222138       0.247275       0.387055
# DiabetesPedigreeFunction    -0.025452  0.127004       0.059303       0.214026
# Age                          0.548665  0.255567       0.240416      -0.121236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.064909  0.012920                 -0.025452
# Glucose                   0.334175  0.222138                  0.127004
# ...

# %%
#remove _____ & write the appropriate function name

plt.figure(figsize=(8, 8))
sns.heatmap(corr_matrix, annot=True)

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 17:
# According to the correlation matrix, the highest correlation is between the variables 'Age' and 'Pregnancies'.
# The lowest correlation is between the variables 'SkinThickness' and 'DiabetesPedigreeFunction'.
# The correlation between the variables 'Age' and 'Pregnancies' is 0.55.

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Q18. Split and scale the data (2 Mark)

# %%
# Split the data into dependent and independent variables
# remove _____ & write the appropriate function variable name
y = pima.Outcome
x = pima.drop('Outcome', axis=1)

# %%
# Using StandarScaler scale the data
# remove _____ & write the appropriate function function name

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(x)

# %%
# Splitting the data into train and test. Use test size as 15%
# remove _____ & complete the code

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=45)

# %% [markdown]
# ### Q19. Train a Logistic Regression Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
# remove _____ & complete the code

# import the model
from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr = LogisticRegression()

# fit the model on the train set
m = lr.fit(x_train, y_train)

# Predict on x_test
y_pred = m.predict(x_test)

# Evaluate the model
print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(m.score(x_train, y_train)))
print('Accuracy of the Logictic Regression model on the test set: {:.2f}'.format(m.score(x_test, y_test)))

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.75
# array([[60, 15],
#        [22, 53]])

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 19:
# The accuracy of the Logistic Regression model on the train set is 0.76.
# The accuracy of the Logistic Regression model on the test set is 0.75.
# The number of True Positives is 53.
# The number of True Negatives is 60.

# %% [markdown]
# ### Q20. Train a Random Forest Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
#remove _____ & complete the code

# Import the Model
from sklearn.ensemble import RandomForestClassifier

# Instantiate the model. 
rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# fit the model on the train set
m2 = rf.fit(x_train, y_train)

# Predict on x_test
y_pred2 = m2.predict(x_test)

# Evaluate the Model
print('Accuracy of Random Forest model on the train set: {:.2f}'.format(m2.score(x_train, y_train)))
print('Accuracy of Random Forest model on the test set: {:.2f}'.format(m2.score(x_test, y_test)))
confusion_matrix(y_test, y_pred2)
# Out:
# Accuracy of Random Forest model on the train set: 0.81
# Accuracy of Random Forest model on the test set: 0.79
# array([[57, 18],
#        [14, 61]])

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 20:
# The accuracy of the Random Forest model on the train set is 0.81.
# The accuracy of the Random Forest model on the test set is 0.79.
# The number of True Positives is 61.
# The number of True Negatives is 57.

# %% [markdown]
# ### Q21. Which model performed better? (1 Mark)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 21:
# The Random Forest model performed better.
# Because the accuracy of the Random Forest model is higher than the accuracy of the Logistic Regression model, as well as the number of True Positives and True Negatives of the Random Forest model is higher than the number of True Positives and True Negatives of the Logistic Regression model.
